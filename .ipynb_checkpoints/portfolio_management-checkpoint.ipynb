# %%
import matplotlib.pyplot as plt
import datetime as datetime
import numpy as np
import pandas as pd
import talib
import seaborn as sns
from time import time
import pytz

# %%
import risk_model
import factorize
import account

# %%
optimal_weights_regularized = pd.read_csv('optimal_weights_regularized.csv',index_col = 'asset')
close = pd.read_csv('close.csv', index_col = 'date')

# %% [markdown]
# # 1 - Portfolio Management

# %% [markdown]
# #### paper account: DU1440139
# #### margin account: U2909804

# %%
portfolio = account.read_positions(subscribe = True, acctCode = 'account number')
# Out:
# PositionEnd
# Reading Portfolio

# %%
portfolio
# Out:
#         Position  marketPrice  marketValue  averageCost  unrealizedPNL  \
# Symbol
# ADSK       -13.0   231.860001     -3014.18   245.899400         182.51
# AMD         47.0    54.400002      2556.80    52.984847          66.51
# BURL        22.0   175.016998      3850.37   181.254923        -137.23
# BWA       -100.0    35.230000     -3523.00    36.166579          93.66
# CACI        26.0   196.190002      5100.94   201.602473        -140.72
# CHD        -62.0    82.129997     -5092.06    82.864300          45.53
# CLX        -35.0   226.500000     -7927.50   216.404580        -353.34
# DHI        -63.0    57.000000     -3591.00    59.174013         136.96
# FISV       122.0    94.360001     11511.92    99.483076        -625.02
# FLIR        67.0    39.700001      2659.90    40.508428         -54.16
# HPE        291.0     9.445250      2748.57     9.341602          30.16
# IBM         93.0   119.570000     11120.01   121.169752        -148.78
# JCOM       543.0    55.681900     30235.27    57.865855       -1185.89
# JWN        165.0    15.360000      2534.40    15.972502        -101.06
# KHC       -225.0    32.509998     -7314.75    32.307264         -45.62
# KO         912.0    45.299999     41313.60    44.009643        1176.80
# LDOS        29.0    85.110001      2468.19    88.971079        -111.97
# LOW       -116.0   136.800003    -15868.80   133.561287        -375.69
# OMC         52.0    54.500801      2834.04    54.685737          -9.62
# PII        -58.0    95.709999     -5551.18    95.672728          -2.16
# PKG        -65.0    98.763397     -6419.62    99.279098          33.52
# PLAY       186.0    11.800000      2194.80    12.396703        -110.99
# POOL       -13.0   276.153015     -3589.99   281.468615          69.10
# SAIC       180.0    69.110001     12439.80    71.884036        -499.33
# SQ         -20.0   120.050003     -2401.00   130.781375         214.63
# THO        -56.0   101.110001     -5662.16   103.672336         143.49
# TSCO      -117.0   135.500000    -15853.50   139.355198         451.06
# WDC        149.0    41.799999      6228.20    42.806703        -150.00
# WING       -21.0   130.250000     -2735.25   136.902076         139.69
#
#         realizedPNL
# Symbol
# ADSK            0.0
# AMD             0.0
# BURL            0.0
# BWA             0.0
# CACI            0.0
# CHD             0.0
# CLX            -0.0
# DHI             0.0
# FISV            0.0
# FLIR            0.0
# HPE             0.0
# IBM             0.0
# JCOM            0.0
# JWN             0.0
# KHC             0.0
# KO              0.0
# LDOS            0.0
# LOW             0.0
# OMC             0.0
# PII             0.0
# PKG             0.0
# PLAY            0.0
# POOL            0.0
# SAIC            0.0
# SQ              0.0
# THO             0.0
# TSCO            0.0
# WDC             0.0
# WING            0.0

# %%
acc = account.read_account(reqId = 0, subscribe = True, acctCode = 'account number')
# Out:
# AccountDownloadEnd. Account: DU1440139
# Reading Account

# %%
all_weights, long, short, grv = risk_model.portfolio_calculation(portfolio)

# %%
x = range(len(all_weights))
y = all_weights.values.flatten()
fig, ax = plt.subplots(figsize=(20, 10))
plt.grid(True)
plt.bar(x, y, width = 0.8, linewidth = 1, color='orange')
plt.xticks(x, tuple(all_weights.index))
plt.tick_params(labelrotation=90)
plt.show()

# %%
long_value = long['marketValue'].sum()
short_value = short['marketValue'].sum()
print ('Buying Power: {} $'.format(np.round(float(acc.loc['BuyingPower',:].values[0]), 4)))
print ('Gross Market Value: {} $'.format(np.round(grv, 4)))
print (' Long Value: {} $'.format(np.round(long_value,4)))
print (' Short Value: {} $'.format(np.round(short_value,4)))
print (' Net Liquidation: {} $'.format(np.round(float(acc.loc['EquityWithLoanValue',:].values[0]),4)))
print (' Unrealize PNL: {} $'.format(np.round(portfolio['unrealizedPNL'].sum()),4))
print (' Loan Value: {} $'.format(np.round(float(acc.loc['GrossPositionValue'][0]) - float(acc.loc['EquityWithLoanValue'][0]), 4)))
print ('#####################################')
print ('Leverage Value: {}'.format(np.round(grv/float(acc.loc['EquityWithLoanValue'][0]), 4)))
print (' Long Leverage Value: {}'.format(np.round(long_value/float(acc.loc['EquityWithLoanValue'][0]), 4)))
print (' Short Leverage Value: {}'.format(np.round(np.abs(short_value)/float(acc.loc['EquityWithLoanValue'][0]), 4)))
# Out:
# Buying Power: 367480.0 $
# Gross Market Value: 228340.8 $
#  Long Value: 139796.81 $
#  Short Value: -88543.99 $
#  Net Liquidation: 153497.0 $
#  Unrealize PNL: -1268.0 $
#  Loan Value: 74844.0 $
# #####################################
# Leverage Value: 1.4876
#  Long Leverage Value: 0.9107
#  Short Leverage Value: 0.5768

# %%
universe = portfolio.index
long_universe = long.index 
short_universe = short.index

# %%
net_liq = np.round(float(acc.loc['EquityWithLoanValue',:].values[0]),4)

# %% [markdown]
# ## 11 - 1 - Projected portfolio balance

# %%
target_leverage = 1.5
grv_target = net_liq * target_leverage
excess_grv = grv_target - grv
print (excess_grv,'$')
marketVal_target = all_weights * grv_target
# Out:
# 1904.7000000000116 $

# %%
balancing_order = marketVal_target['weights'] - portfolio['marketValue']
df_port = portfolio['marketPrice']
action_balance = pd.DataFrame(index = df_port.index, columns = ['shares'])
action_balance['shares'] = np.round(balancing_order / df_port,2)
to_drop = action_balance[action_balance['shares']==0.0].index
action_balance.drop(to_drop,axis=0,inplace=True)

# %%
grv_target
# Out:
# 230245.5

# %%
val = account.read_nextvalidid(reqId=-1)
# Out:
# NextValidId: 1067

# %%
#account.rebalancing_to_leverage(action_balance = action_balance , order_id = val)

# %% [markdown]
# ## 11 - 2 - Filtering stock with significant market value

# %%
df_c = pd.DataFrame(data=close[optimal_weights_regularized.index].iloc[-1].values,
                   index = close[optimal_weights_regularized.index].iloc[-1].index,
                   columns = ['close'])
df_c.index.name = 'asset'

# %%
# dropping securities with less than 1% allocation 
optimal_selected = optimal_weights_regularized[optimal_weights_regularized['optimal_weights'] != 0.00]

# %%
print ('##########################################################')
print ('dropping {} securities which have less than 1% allocation'.format(len(optimal_weights_regularized[optimal_weights_regularized['optimal_weights'] == 0.00].index)))
print ('##########################################################')
# Out:
# ##########################################################
# dropping 0 securities which have less than 1% allocation
# ##########################################################

# %% [markdown]
# ## 11 - 4 - Processing data for execution

# %%
stock_to_balance = portfolio.index & optimal_selected.index
stock_to_close = portfolio.index ^ stock_to_balance

# %%
df_c_target = df_c.reindex(optimal_selected.index)
shares_target_float = (optimal_selected * grv_target)['optimal_weights']/df_c_target['close']

# %%
portfolio_shares_float = portfolio['marketValue'] / portfolio['marketPrice']

# %%
# Rebalance to optimal weights
action_final = pd.DataFrame(index = shares_target_float.index, columns = ['shares'])

for i in shares_target_float.index:
    
    if (i in stock_to_balance) and (i not in action_balance.index):
        action_final.loc[i,'shares'] = shares_target_float[i] - portfolio_shares_float[i]
        
    elif (i in stock_to_balance) and (i in action_balance.index):
        action_final.loc[i,'shares'] = shares_target_float[i] - portfolio_shares_float[i] - action_balance['shares'][i]

    elif (i in action_balance.index) and (i not in stock_to_balance):
        action_final.loc[i,'shares'] = shares_target_float[i] - action_balance['shares'][i]
    else:
        action_final.loc[i,'shares'] = shares_target_float[i]

# %%
# rename columns
portfolio_shares_float = pd.DataFrame(portfolio_shares_float,columns = ['portfolio_shares'],index=portfolio_shares_float.index)
shares_target_float = pd.DataFrame(shares_target_float,columns = ['target_shares'],index=shares_target_float.index)
action_balance.columns = ['balance_lev_shares']
action_final.columns = ['final_action_shares']

# %%
# replacing too small actions value with nan value
treshold_long = 1
treshold_short = -1

action_final[(action_final['final_action_shares']>0) & (action_final['final_action_shares']< treshold_long)] = np.nan
action_final[(action_final['final_action_shares']<0) & (action_final['final_action_shares']> treshold_short)] = np.nan
action_final[action_final['final_action_shares']==0.0] = np.nan
action_final.dropna(axis=0,inplace=True)
action_final['final_action_shares'] = pd.to_numeric(action_final['final_action_shares'], errors='coerce')

# %%
action_conc = pd.concat([portfolio_shares_float,
                         action_balance,
                         action_final,
                         shares_target_float],axis=1,sort ='False')

# %%
isna_df = action_conc.isna()
for i in action_conc.index:
    if (isna_df.loc[i]['final_action_shares'] == True) & (isna_df.loc[i]['target_shares'] == False) :
        action_conc.drop(i, inplace = True)

# %%
action_conc.round(2)
# Out:
#       portfolio_shares  balance_lev_shares  final_action_shares  target_shares
# ADSK             -13.0               -0.11                  NaN            NaN
# AMD               47.0                0.40                  NaN            NaN
# AMZN               NaN                 NaN                -3.31          -3.31
# BERY               NaN                 NaN              -125.79        -125.79
# BURL              22.0                0.23                  NaN            NaN
# BWA             -100.0               -0.65                -3.14        -103.79
# CACI              26.0                0.17               106.23         132.40
# CHD              -62.0               -0.52                  NaN            NaN
# CLGX               NaN                 NaN               -73.75         -73.75
# CLX              -35.0               -0.27                  NaN            NaN
# DHI              -63.0               -0.42                  NaN            NaN
# FB                 NaN                 NaN               -34.58         -34.58
# FEYE               NaN                 NaN               189.45         189.45
# FISV             122.0                0.98               -99.27          23.71
# FLIR              67.0                0.28               310.85         378.13
# HD                 NaN                 NaN               -24.89         -24.89
# HPE              291.0                1.52              -181.26         111.26
# IBM               93.0                0.78                  NaN            NaN
# JCOM             543.0                4.48              -220.72         326.76
# JWN              165.0                1.39                  NaN            NaN
# K                  NaN                 NaN               -87.80         -87.80
# KHC             -225.0               -1.63                32.00        -194.63
# KO               912.0                7.46              -576.83         342.63
# LDOS              29.0                0.22               156.68         185.90
# LOW             -116.0               -0.97                91.60         -25.37
# MPWR               NaN                 NaN               -27.79         -27.79
# MSI                NaN                 NaN                84.42          84.42
# MU                 NaN                 NaN               107.54         107.54
# OMC               52.0                0.39                  NaN            NaN
# PII              -58.0               -0.46               -11.05         -69.51
# PKG              -65.0               -0.51                  NaN            NaN
# PLAY             186.0                1.32                  NaN            NaN
# POOL             -13.0               -0.09               -15.74         -28.83
# SAIC             180.0                1.57               -27.14         154.43
# SCI                NaN                 NaN               105.80         105.80
# SQ               -20.0               -0.14               -14.59         -34.73
# THO              -56.0               -0.47                  NaN            NaN
# TPR                NaN                 NaN               286.88         286.88
# TSCO            -117.0               -0.93                53.31         -64.62
# UBER               NaN                 NaN                64.30          64.30
# WDC              149.0                1.38               -20.91         129.47
# WING             -21.0               -0.21                -4.77         -25.98

# %% [markdown]
# ## 11 - 5 - Executing on TWS

# %%
op = account.cancel_openorders()
# Out:
# open order ended

# %%
# closing positions not in shares target
next_order_id = account.closing_positions(stock_to_close = stock_to_close, portfolio = portfolio , order_id = val)
# Out:
# app is running ...
# closing 20 positions which are not present in action
# closing position for ABT is: 25
# closing position for AMAT is: 79
# closing position for BLK is: 17
# closing position for C is: 46
# closing position for CAT is: 18
# closing position for D is: 257
# closing position for FDX is: 35
# closing position for HCA is: 74
# closing position for HON is: 33
# closing position for INTU is: 8
# closing position for KR is: 70
# closing position for MAR is: 28
# closing position for MDT is: 207
# closing position for PYPL is: 106
# closing position for REGN is: 7
# closing position for SPGI is: 42
# closing position for TMUS is: 65
# closing position for TWTR is: 158
# closing position for UAL is: 140
# closing position for UPS is: 21

# %%
next_order_id
# Out:
# 1038

# %%
action_final = action_final.astype('int')
account.placing_final_orders(action_final=action_final, order_id = next_order_id)
# Out:
# buy order quantity placed for JWN is: 165
# sell order quantity placed for WING is: 21
# buy order quantity placed for BURL is: 22
# sell order quantity placed for BWA is: 100
# sell order quantity placed for DHI is: 63
# buy order quantity placed for OMC is: 52
# buy order quantity placed for PLAY is: 186
# sell order quantity placed for TSCO is: 117
# sell order quantity placed for THO is: 56
# sell order quantity placed for POOL is: 13
# sell order quantity placed for PKG is: 65
# sell order quantity placed for PII is: 58
# sell order quantity placed for LOW is: 45
# buy order quantity placed for JCOM is: 543
# buy order quantity placed for CACI is: 26
# buy order quantity placed for HPE is: 291
# buy order quantity placed for LDOS is: 29
# buy order quantity placed for FLIR is: 67
# buy order quantity placed for SAIC is: 180
# buy order quantity placed for IBM is: 36
# buy order quantity placed for AMD is: 2
# buy order quantity placed for WDC is: 149
# sell order quantity placed for ADSK is: 13
# buy order quantity placed for FISV is: 3
# sell order quantity placed for SQ is: 20
# buy order quantity placed for CLX is: 18
# sell order quantity placed for KO is: 305
# sell order quantity placed for CHD is: 62
# sell order quantity placed for KHC is: 225

# %%
open_orders_all = account.get_openorders()
# Out:
# open order ended
# open order ended

# %%
open_orders_all
# Out:
#      action executed_orders type algoStrategy                algoParams  \
# KO     SELL             305  MKT     Adaptive  adaptivePriority=Normal;
# KR      BUY              70  MKT     Adaptive  adaptivePriority=Normal;
# ADSK   SELL              13  MKT     Adaptive  adaptivePriority=Normal;
# FISV    BUY               3  MKT     Adaptive  adaptivePriority=Normal;
# FDX     BUY              35  MKT     Adaptive  adaptivePriority=Normal;
# HON     BUY              33  MKT     Adaptive  adaptivePriority=Normal;
# SQ     SELL              20  MKT     Adaptive  adaptivePriority=Normal;
# HCA    SELL              74  MKT     Adaptive  adaptivePriority=Normal;
# FLIR    BUY              67  MKT     Adaptive  adaptivePriority=Normal;
# C      SELL              46  MKT     Adaptive  adaptivePriority=Normal;
# WDC     BUY             149  MKT     Adaptive  adaptivePriority=Normal;
# IBM     BUY              36  MKT     Adaptive  adaptivePriority=Normal;
# CAT     BUY              18  MKT     Adaptive  adaptivePriority=Normal;
# ABT    SELL              25  MKT     Adaptive  adaptivePriority=Normal;
# SAIC    BUY             180  MKT     Adaptive  adaptivePriority=Normal;
# D       BUY             257  MKT     Adaptive  adaptivePriority=Normal;
# HPE     BUY             291  MKT     Adaptive  adaptivePriority=Normal;
# BLK     BUY              17  MKT     Adaptive  adaptivePriority=Normal;
# LDOS    BUY              29  MKT     Adaptive  adaptivePriority=Normal;
# AMAT   SELL              79  MKT     Adaptive  adaptivePriority=Normal;
# CACI    BUY              26  MKT     Adaptive  adaptivePriority=Normal;
# LOW    SELL              45  MKT     Adaptive  adaptivePriority=Normal;
# PKG    SELL              65  MKT     Adaptive  adaptivePriority=Normal;
# PII    SELL              58  MKT     Adaptive  adaptivePriority=Normal;
# THO    SELL              56  MKT     Adaptive  adaptivePriority=Normal;
# POOL   SELL              13  MKT     Adaptive  adaptivePriority=Normal;
# TSCO   SELL             117  MKT     Adaptive  adaptivePriority=Normal;
# OMC     BUY              52  MKT     Adaptive  adaptivePriority=Normal;
# PLAY    BUY             186  MKT     Adaptive  adaptivePriority=Normal;
# DHI    SELL              63  MKT     Adaptive  adaptivePriority=Normal;
# BURL    BUY              22  MKT     Adaptive  adaptivePriority=Normal;
# JWN     BUY             165  MKT     Adaptive  adaptivePriority=Normal;
# BWA    SELL             100  MKT     Adaptive  adaptivePriority=Normal;
# UPS     BUY              21  MKT     Adaptive  adaptivePriority=Normal;
# UAL     BUY             140  MKT     Adaptive  adaptivePriority=Normal;
# TMUS    BUY              65  MKT     Adaptive  adaptivePriority=Normal;
# REGN    BUY               7  MKT     Adaptive  adaptivePriority=Normal;
# PYPL    BUY             106  MKT     Adaptive  adaptivePriority=Normal;
# INTU   SELL               8  MKT     Adaptive  adaptivePriority=Normal;
# CHD    SELL              62  MKT     Adaptive  adaptivePriority=Normal;
# TWTR   SELL             158  MKT     Adaptive  adaptivePriority=Normal;
# AMD     BUY               2  MKT     Adaptive  adaptivePriority=Normal;
# KHC    SELL             225  MKT     Adaptive  adaptivePriority=Normal;
# SPGI    BUY              42  MKT     Adaptive  adaptivePriority=Normal;
# MDT    SELL             207  MKT     Adaptive  adaptivePriority=Normal;
# CLX     BUY              18  MKT     Adaptive  adaptivePriority=Normal;
# MAR    SELL              28  MKT     Adaptive  adaptivePriority=Normal;
# JCOM    BUY             543  MKT     Adaptive  adaptivePriority=Normal;
#
#             status
# KO    PreSubmitted
# KR    PreSubmitted
# ADSK  PreSubmitted
# FISV  PreSubmitted
# FDX   PreSubmitted
# HON   PreSubmitted
# SQ    PreSubmitted
# HCA   PreSubmitted
# FLIR  PreSubmitted
# C     PreSubmitted
# WDC   PreSubmitted
# IBM   PreSubmitted
# CAT   PreSubmitted
# ABT   PreSubmitted
# SAIC  PreSubmitted
# D     PreSubmitted
# HPE   PreSubmitted
# BLK   PreSubmitted
# LDOS  PreSubmitted
# AMAT  PreSubmitted
# CACI  PreSubmitted
# LOW   PreSubmitted
# PKG   PreSubmitted
# PII   PreSubmitted
# THO   PreSubmitted
# POOL  PreSubmitted
# TSCO  PreSubmitted
# OMC   PreSubmitted
# PLAY  PreSubmitted
# DHI   PreSubmitted
# BURL  PreSubmitted
# JWN   PreSubmitted
# BWA   PreSubmitted
# UPS   PreSubmitted
# UAL   PreSubmitted
# TMUS  PreSubmitted
# REGN  PreSubmitted
# PYPL  PreSubmitted
# INTU  PreSubmitted
# CHD   PreSubmitted
# TWTR  PreSubmitted
# AMD   PreSubmitted
# KHC   PreSubmitted
# SPGI  PreSubmitted
# MDT   PreSubmitted
# CLX   PreSubmitted
# MAR   PreSubmitted
# JCOM  PreSubmitted

# %%
not_executed_action = open_orders_all.index ^ action_conc.index                        
print ('{} not executed'.format(list(not_executed_action)))
# Out:
# ['WING'] not executed

# %%
execution = pd.concat([action_conc, open_orders_all[['executed_orders']]],axis=1, sort=True)

# %%
execution
# Out:
#       portfolio_shares  balance_lev_shares final_action_shares  target_shares  \
# ABT                NaN                 NaN             25.9971      25.997125
# AMAT               NaN                 NaN             79.0067      79.006680
# AMD               41.0                0.78             3.25204      46.032036
# AMZN              -7.0               -0.13                 NaN            NaN
# ATVI              29.0                0.48                 NaN            NaN
# BLK              -24.0               -0.48             8.23251     -17.247490
# BYND             -14.0               -0.24                 NaN            NaN
# C                  NaN                 NaN             46.5148      46.514825
# CAT                NaN                 NaN            -18.8431     -18.843084
# CLX              -20.0               -0.43            -32.1279     -53.557942
# COST               7.0                0.13                 NaN            NaN
# CRM               48.0                0.97                 NaN            NaN
# CSCO             103.0                2.14                 NaN            NaN
# D               -143.0               -2.65             -114.84    -260.490023
# ENPH              50.0                0.94                 NaN            NaN
# FDX                NaN                 NaN            -35.4583     -35.458256
# FIS              101.0                1.98                 NaN            NaN
# FISV             163.0                3.11            -44.6285     121.481511
# HCA                NaN                 NaN              74.812      74.812013
# HON                NaN                 NaN            -33.3725     -33.372477
# IBM              114.0                2.20            -57.1624      59.037589
# ILMN             -12.0               -0.23                 NaN            NaN
# INTC              78.0                1.68                 NaN            NaN
# INTU               NaN                 NaN             8.04902       8.049019
# KO                 NaN                 NaN             1217.41    1217.413702
# KR                 NaN                 NaN            -70.5693     -70.569308
# LOW                NaN                 NaN            -71.2837     -71.283672
# LULU             -46.0               -0.84                 NaN            NaN
# MAR                NaN                 NaN             28.4928      28.492772
# MDT                NaN                 NaN             207.836     207.836431
# MELI              -6.0               -0.12                 NaN            NaN
# MSFT             175.0                3.39                 NaN            NaN
# ORCL              84.0                1.55                 NaN            NaN
# PYPL            -113.0               -2.18             7.20529    -107.974718
# REGN               NaN                 NaN            -7.54451      -7.544507
# SHOP              -5.0               -0.11                 NaN            NaN
# SNAP             102.0                2.15                 NaN            NaN
# SPGI             -34.0               -0.68            -7.34621     -43.026213
# TMUS               NaN                 NaN            -65.7663     -65.766302
# TTD               -5.0               -0.12                 NaN            NaN
# TWTR               NaN                 NaN             158.775     158.774871
# UAL                NaN                 NaN            -140.237    -140.237458
# UBER              69.0                1.07                 NaN            NaN
# UPS                NaN                 NaN            -21.4891     -21.489051
# W                -11.0               -0.22                 NaN            NaN
#
#      executed_orders
# ABT               25
# AMAT              79
# AMD                3
# AMZN               7
# ATVI              30
# BLK                8
# BYND              14
# C                 46
# CAT               18
# CLX               32
# COST               7
# CRM               48
# CSCO             103
# D                114
# ENPH              50
# FDX               35
# FIS              101
# FISV              44
# HCA               74
# HON               33
# IBM               57
# ILMN              12
# INTC              78
# INTU               8
# KO               617
# KR                70
# LOW               71
# LULU              46
# MAR               28
# MDT              207
# MELI               7
# MSFT             175
# ORCL              84
# PYPL               7
# REGN               7
# SHOP               5
# SNAP             103
# SPGI               7
# TMUS              65
# TTD                6
# TWTR             158
# UAL              140
# UBER              70
# UPS               21
# W                 11

# %% [markdown]
# ## 11 - 6 - Commission report of last realized trades

# %%
df = account.commission_report(acctCode = 'account number', time= '20200601')

# %%
execution_date = '2020-07-13'

# %%
df
# Out:
#                     ticker shares action   price marketValue RealizedPNL  \
# time
# 2020-07-13 09:30:01    WDC    100    BOT    42.8        4280        OPEN
# 2020-07-13 09:30:01   PYPL    106    BOT  180.74     19158.4    -1578.56
# 2020-07-13 09:30:01   INTU      8    SLD  308.81     2470.48     182.193
# 2020-07-13 09:30:01    KHC    225    SLD   32.31     7269.75        OPEN
# 2020-07-13 09:30:02    WDC     49    BOT    42.8      2097.2        OPEN
# 2020-07-13 09:30:03   WING     21    SLD  136.92     2875.32        OPEN
# 2020-07-13 09:30:03   PLAY    186    BOT   12.39     2304.54        OPEN
# 2020-07-13 09:30:05    CLX     18    BOT  230.96     4157.28    -262.405
# 2020-07-13 09:30:10   TSCO    117    SLD  139.36     16305.1        OPEN
# 2020-07-13 09:30:11    HPE    291    BOT    9.34     2717.94        OPEN
# 2020-07-13 09:30:12   TMUS     65    BOT  106.94      6951.1    -70.1634
# 2020-07-13 09:30:12    UAL    100    BOT    33.2        3320     4.22696
# 2020-07-13 09:30:12    UAL     40    BOT    33.2        1328     1.69078
# 2020-07-13 09:30:16   AMAT     79    SLD   63.09     4984.11     366.427
# 2020-07-13 09:30:19     KO      5    SLD   45.44       227.2     7.13366
# 2020-07-13 09:30:19     KO    200    SLD   45.47        9094     291.346
# 2020-07-13 09:30:19     KO    100    SLD   45.44        4544     142.673
# 2020-07-13 09:30:20    PII     58    SLD   95.68     5549.44        OPEN
# 2020-07-13 09:30:20   REGN      7    BOT   624.7      4372.9    -106.155
