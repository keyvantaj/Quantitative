# %%
import matplotlib.pyplot as plt
import datetime as datetime
import numpy as np
import pandas as pd
import talib
import seaborn as sns
from time import time
import pytz

# %%
import risk_model
import factorize
import account

# %%
optimal_weights_regularized = pd.read_csv('output/optimal_weights_regularized.csv',index_col = 'asset')
close = pd.read_csv('data/close.csv', index_col = 'date')

# %% [markdown]
# # 1 - Portfolio Management

# %% [markdown]
# #### paper account: DU1440139
# #### margin account: U2909804

# %%
account_number = 'DU1440139'

# %%
portfolio = account.read_positions(subscribe = True, acctCode = account_number)
# Out:
# PositionEnd
# Reading Portfolio

# %%
portfolio
# Out:
#         Position  marketPrice  marketValue  averageCost  unrealizedPNL  \
# Symbol
# ADSK       -13.0   237.699997     -3090.10   245.899400         106.59
# AMD         47.0    55.310001      2599.57    52.984847         109.28
# BURL        22.0   193.500000      4257.00   181.254923         269.39
# BWA       -100.0    37.389999     -3739.00    36.166579        -122.34
# CACI        26.0   197.475998      5134.38   201.602473        -107.29
# CHD        -62.0    84.370003     -5230.94    82.864300         -93.35
# CLX        -35.0   229.140015     -8019.90   216.404580        -445.74
# DHI        -63.0    63.049999     -3972.15    59.174013        -244.19
# FISV       122.0   102.500000     12505.00    99.483076         368.06
# FLIR        67.0    41.509998      2781.17    40.508428          67.11
# HPE        291.0     9.680000      2816.88     9.341602          98.47
# IBM         93.0   125.230003     11646.39   121.169752         377.60
# JCOM       543.0    56.310501     30576.60    57.865855        -844.56
# JWN        165.0    15.120000      2494.80    15.972502        -140.66
# KHC       -225.0    34.919998     -7857.00    32.307264        -587.87
# KO         912.0    46.840000     42718.08    44.009643        2581.29
# LDOS        29.0    88.189598      2557.50    88.971079         -22.66
# LOW       -116.0   144.500000    -16762.00   133.561287       -1268.89
# OMC         52.0    55.696899      2896.24    54.685737          52.58
# PII        -58.0    96.472900     -5595.43    95.672728         -46.41
# PKG        -65.0   104.671997     -6803.68    99.279098        -350.54
# PLAY       186.0    13.360000      2484.96    12.396703         179.17
# POOL       -13.0   294.350006     -3826.55   281.468615        -167.46
# SAIC       180.0    71.900002     12942.00    71.884036           2.87
# SQ         -20.0   121.320000     -2426.40   130.781375         189.23
# THO        -56.0   110.040001     -6162.24   103.672336        -356.59
# TSCO      -117.0   142.119995    -16628.04   139.355198        -323.48
# WDC        149.0    43.400002      6466.60    42.806703          88.40
# WING       -21.0   136.759995     -2871.96   136.902076           2.98
#
#         realizedPNL
# Symbol
# ADSK            0.0
# AMD             0.0
# BURL            0.0
# BWA             0.0
# CACI            0.0
# CHD             0.0
# CLX            -0.0
# DHI             0.0
# FISV            0.0
# FLIR            0.0
# HPE             0.0
# IBM             0.0
# JCOM            0.0
# JWN             0.0
# KHC             0.0
# KO              0.0
# LDOS            0.0
# LOW             0.0
# OMC             0.0
# PII             0.0
# PKG             0.0
# PLAY            0.0
# POOL            0.0
# SAIC            0.0
# SQ              0.0
# THO             0.0
# TSCO            0.0
# WDC             0.0
# WING            0.0

# %%
acc = account.read_account(reqId = 0, subscribe = True, acctCode = account_number)
# Out:
# AccountDownloadEnd. Account: DU1440139
# Reading Account

# %%
all_weights, long, short, grv = risk_model.portfolio_calculation(portfolio)

# %%
x = range(len(all_weights))
y = all_weights.values.flatten()
fig, ax = plt.subplots(figsize=(20, 10))
plt.grid(True)
plt.bar(x, y, width = 0.8, linewidth = 1, color='orange')
plt.xticks(x, tuple(all_weights.index))
plt.tick_params(labelrotation=90)
plt.title('actual portfolio')
plt.show()

# %%
optimal_weights_regularized
# Out:
#        optimal_weights
# asset
# ANSS      1.366591e-01
# AXP       4.464998e-02
# BURL      1.774744e-02
# CAT      -4.246494e-02
# CHGG     -1.225638e-02
# DLR      -2.045405e-02
# DTE      -1.774377e-02
# ENPH      3.563077e-03
# ETFC     -3.482810e-02
# FISV      1.173591e-08
# GIS      -3.396212e-02
# GS       -4.549671e-02
# HCA       1.926067e-02
# IBM       4.095789e-02
# ILMN     -2.739834e-02
# KO        2.128963e-02
# LOW      -1.650289e-02
# MDLZ      4.647915e-02
# MS       -8.089290e-03
# MSI       7.938915e-02
# OKE       2.559438e-02
# PNC       1.289028e-02
# PYPL     -4.309876e-02
# ROST      1.170567e-01
# SIRI      2.746212e-02
# SPGI     -1.797284e-02
# TSCO     -1.269994e-02
# ULTA      7.000388e-03
# UNP      -4.478364e-02
# WIX      -2.224822e-02

# %%
x = range(len(optimal_weights_regularized.sort_values(by='optimal_weights')))
y = optimal_weights_regularized.values.flatten()
fig, ax = plt.subplots(figsize=(20, 10))
plt.grid(True)
plt.bar(x, y, width = 0.8, linewidth = 1, color='green')
plt.xticks(x, tuple(optimal_weights_regularized.index))
plt.tick_params(labelrotation=90)
plt.title('future balance portfolio')
plt.show()

# %%
long_value = long['marketValue'].sum()
short_value = short['marketValue'].sum()
print ('Buying Power: {} $'.format(np.round(float(acc.loc['BuyingPower',:].values[0]), 4)))
print ('Gross Market Value: {} $'.format(np.round(grv, 4)))
print (' Long Value: {} $'.format(np.round(long_value,4)))
print (' Short Value: {} $'.format(np.round(short_value,4)))
print (' Net Liquidation: {} $'.format(np.round(float(acc.loc['EquityWithLoanValue',:].values[0]),4)))
print (' Unrealize PNL: {} $'.format(np.round(portfolio['unrealizedPNL'].sum()),4))
print (' Loan Value: {} $'.format(np.round(float(acc.loc['GrossPositionValue'][0]) - float(acc.loc['EquityWithLoanValue'][0]), 4)))
print ('#####################################')
print ('Leverage Value: {}'.format(np.round(grv/float(acc.loc['EquityWithLoanValue'][0]), 4)))
print (' Long Leverage Value: {}'.format(np.round(long_value/float(acc.loc['EquityWithLoanValue'][0]), 4)))
print (' Short Leverage Value: {}'.format(np.round(np.abs(short_value)/float(acc.loc['EquityWithLoanValue'][0]), 4)))
# Out:
# Buying Power: 360195.0 $
# Gross Market Value: 237862.56 $
#  Long Value: 144877.17 $
#  Short Value: -92985.39 $
#  Net Liquidation: 154164.0 $
#  Unrealize PNL: -629.0 $
#  Loan Value: 83699.0 $
# #####################################
# Leverage Value: 1.5429
#  Long Leverage Value: 0.9398
#  Short Leverage Value: 0.6032

# %%
universe = portfolio.index
long_universe = long.index 
short_universe = short.index

# %%
net_liq = np.round(float(acc.loc['EquityWithLoanValue',:].values[0]),4)

# %% [markdown]
# ## 11 - 1 - Projected portfolio balance

# %%
target_leverage = 1.5
grv_target = net_liq * target_leverage
excess_grv = grv_target - grv
print (excess_grv,'$')
marketVal_target = all_weights * grv_target
# Out:
# -6616.560000000056 $

# %%
balancing_order = marketVal_target['weights'] - portfolio['marketValue']
df_port = portfolio['marketPrice']
action_balance = pd.DataFrame(index = df_port.index, columns = ['shares'])
action_balance['shares'] = np.round(balancing_order / df_port,2)
to_drop = action_balance[action_balance['shares']==0.0].index
action_balance.drop(to_drop,axis=0,inplace=True)

# %%
grv_target
# Out:
# 231246.0

# %%
val = account.read_nextvalidid(reqId=-1)
# Out:
# NextValidId: 1120
# NextValidId: 1120

# %%
#account.rebalancing_to_leverage(action_balance = action_balance , order_id = val)

# %% [markdown]
# ## 11 - 2 - Filtering stock with significant market value

# %%
df_c = pd.DataFrame(data=close[optimal_weights_regularized.index].iloc[-1].values,
                   index = close[optimal_weights_regularized.index].iloc[-1].index,
                   columns = ['close'])
df_c.index.name = 'asset'

# %%
optimal_weights_regularized = optimal_weights_regularized.round(2)

# %%
# dropping securities with less than 1% allocation 
optimal_selected = optimal_weights_regularized[optimal_weights_regularized['optimal_weights'] != 0.00]

# %%
print ('##########################################################')
print ('dropping {} securities which have less than 1% allocation'.format(len(optimal_weights_regularized[optimal_weights_regularized['optimal_weights'] == 0.00].index)))
print ('##########################################################')
# Out:
# ##########################################################
# dropping 2 securities which have less than 1% allocation
# ##########################################################

# %% [markdown]
# ## 11 - 4 - Processing data for execution

# %%
stock_to_balance = portfolio.index & optimal_selected.index
stock_to_close = portfolio.index ^ stock_to_balance

# %%
df_c_target = df_c.reindex(optimal_selected.index)
shares_target_float = (optimal_selected * grv_target)['optimal_weights']/df_c_target['close']

# %%
portfolio_shares_float = portfolio['marketValue'] / portfolio['marketPrice']

# %%
# Rebalance to optimal weights
action_final = pd.DataFrame(index = shares_target_float.index, columns = ['shares'])

for i in shares_target_float.index:
    
    if (i in stock_to_balance) and (i not in action_balance.index):
        action_final.loc[i,'shares'] = shares_target_float[i] - portfolio_shares_float[i]
        
    elif (i in stock_to_balance) and (i in action_balance.index):
        action_final.loc[i,'shares'] = shares_target_float[i] - (portfolio_shares_float[i] + action_balance['shares'][i])

    elif (i in action_balance.index) and (i not in stock_to_balance):
        action_final.loc[i,'shares'] = shares_target_float[i] + action_balance['shares'][i]
    else:
        action_final.loc[i,'shares'] = shares_target_float[i]

# %%
# rename columns
portfolio_shares_float = pd.DataFrame(portfolio_shares_float,columns = ['portfolio_shares'],index=portfolio_shares_float.index)
shares_target_float = pd.DataFrame(shares_target_float,columns = ['target_shares_not_balanced'],index=shares_target_float.index)


action_balance.columns = ['balance_lev_shares']
action_final.columns = ['final_action_shares']

# %%
# replacing too small actions value with nan value
treshold_long = 1
treshold_short = -1

action_final[(action_final['final_action_shares']>0) & (action_final['final_action_shares']< treshold_long)] = np.nan
action_final[(action_final['final_action_shares']<0) & (action_final['final_action_shares']> treshold_short)] = np.nan
action_final[action_final['final_action_shares']==0.0] = np.nan
action_final.dropna(axis=0,inplace=True)
action_final['final_action_shares'] = pd.to_numeric(action_final['final_action_shares'], errors='coerce')

# %%
action_conc = pd.concat([portfolio_shares_float,
                         action_balance,
                         shares_target_float,
                         action_final],axis=1,sort ='False')

# %%
isna_df = action_conc.isna()
for i in action_conc.index:
    if (isna_df.loc[i]['final_action_shares'] == True) & (isna_df.loc[i]['target_shares_not_balanced'] == False) :
        action_conc.drop(i, inplace = True)

# %%
action_conc.round(2)
# Out:
#       portfolio_shares  balance_lev_shares  target_shares_not_balanced  \
# ADSK             -13.0                0.35                         NaN
# AMD               47.0               -1.43                         NaN
# ANSS               NaN                 NaN                      104.94
# AXP                NaN                 NaN                      108.48
# BWA             -100.0                2.90                         NaN
# CACI              26.0               -0.71                         NaN
# CAT                NaN                 NaN                      -71.73
# CHD              -62.0                1.70                         NaN
# CHGG               NaN                 NaN                      -38.83
# CLX              -35.0                0.99                         NaN
# DHI              -63.0                1.75                         NaN
# DLR                NaN                 NaN                      -32.90
# DTE                NaN                 NaN                      -36.80
# ENPH               NaN                 NaN                       13.89
# ETFC               NaN                 NaN                     -148.76
# FISV             122.0               -3.33                        0.00
# FLIR              67.0               -1.82                         NaN
# GIS                NaN                 NaN                     -121.50
# GS                 NaN                 NaN                      -49.77
# HCA                NaN                 NaN                       41.99
# HPE              291.0               -9.11                         NaN
# IBM               93.0               -2.52                       75.70
# ILMN               NaN                 NaN                      -16.51
# JCOM             543.0              -15.30                         NaN
# JWN              165.0               -4.41                         NaN
# KHC             -225.0                6.47                         NaN
# KO               912.0              -25.33                      105.15
# LDOS              29.0               -0.68                         NaN
# LOW             -116.0                3.18                      -26.43
# MDLZ               NaN                 NaN                      198.78
# MS                 NaN                 NaN                      -35.69
# MSI                NaN                 NaN                      133.34
# OKE                NaN                 NaN                      206.44
# OMC               52.0               -1.35                         NaN
# PII              -58.0                1.67                         NaN
# PKG              -65.0                1.82                         NaN
# PLAY             186.0               -5.99                         NaN
# PNC                NaN                 NaN                       28.93
# POOL             -13.0                0.35                         NaN
# PYPL               NaN                 NaN                      -57.30
# ROST               NaN                 NaN                      315.53
# SAIC             180.0               -5.04                         NaN
# SIRI               NaN                 NaN                     1078.18
# SPGI               NaN                 NaN                      -11.72
# SQ               -20.0                0.56                         NaN
# THO              -56.0                1.57                         NaN
# TSCO            -117.0                3.26                      -20.86
# ULTA               NaN                 NaN                        7.97
# UNP                NaN                 NaN                      -57.14
# WDC              149.0               -4.07                         NaN
# WING             -21.0                0.54                         NaN
# WIX                NaN                 NaN                      -19.03
#
#       final_action_shares
# ADSK                  NaN
# AMD                   NaN
# ANSS               104.94
# AXP                108.48
# BWA                   NaN
# CACI                  NaN
# CAT                -71.73
# CHD                   NaN
# CHGG               -38.83
# CLX                   NaN
# DHI                   NaN
# DLR                -32.90
# DTE                -36.80
# ENPH                13.89
# ETFC              -148.76
# FISV              -118.67
# FLIR                  NaN
# GIS               -121.50
# GS                 -49.77
# HCA                 41.99
# HPE                   NaN
# IBM                -14.78
# ILMN               -16.51
# JCOM                  NaN
# JWN                   NaN
# KHC                   NaN
# KO                -781.52
# LDOS                  NaN
# LOW                 86.39
# MDLZ               198.78
# MS                 -35.69
# MSI                133.34
# OKE                206.44
# OMC                   NaN
# PII                   NaN
# PKG                   NaN
# PLAY                  NaN
# PNC                 28.93
# POOL                  NaN
# PYPL               -57.30
# ROST               315.53
# SAIC                  NaN
# SIRI              1078.18
# SPGI               -11.72
# SQ                    NaN
# THO                   NaN
# TSCO                92.88
# ULTA                 7.97
# UNP                -57.14
# WDC                   NaN
# WING                  NaN
# WIX                -19.03

# %% [markdown]
# ## 11 - 5 - Executing on TWS

# %%
op = account.cancel_openorders()
# Out:
# open order ended

# %%
# closing positions not in shares target
if not stock_to_close.empty:
    next_order_id = account.closing_positions(stock_to_close = stock_to_close,
                                              portfolio = portfolio , 
                                              order_id = val)
else:
    print ('There is not stock to close...')
    next_order_id = val
# Out:
# app is running ...
# closing 23 positions which are not present in action
# closing position for ADSK is: 13
# closing position for AMD is: 47
# closing position for BWA is: 100
# closing position for CACI is: 26
# closing position for CHD is: 62
# closing position for CLX is: 35
# closing position for DHI is: 63
# closing position for FLIR is: 67
# closing position for HPE is: 291
# closing position for JCOM is: 543
# closing position for JWN is: 165
# closing position for KHC is: 225
# closing position for LDOS is: 29
# closing position for OMC is: 52
# closing position for PII is: 58
# closing position for PKG is: 65
# closing position for PLAY is: 186
# closing position for POOL is: 13
# closing position for SAIC is: 180
# closing position for SQ is: 20
# closing position for THO is: 56
# closing position for WDC is: 149
# closing position for WING is: 21

# %%
action_final = action_final.astype('int')
account.placing_final_orders(action_final=action_final, order_id = next_order_id)
# Out:
# buy order quantity placed for ANSS is: 104
# buy order quantity placed for AXP is: 108
# sell order quantity placed for CAT is: 71
# sell order quantity placed for CHGG is: 38
# sell order quantity placed for DLR is: 32
# sell order quantity placed for DTE is: 36
# buy order quantity placed for ENPH is: 13
# sell order quantity placed for ETFC is: 148
# sell order quantity placed for FISV is: 118
# sell order quantity placed for GIS is: 121
# sell order quantity placed for GS is: 49
# buy order quantity placed for HCA is: 42
# sell order quantity placed for IBM is: 14
# sell order quantity placed for ILMN is: 16
# sell order quantity placed for KO is: 782
# buy order quantity placed for LOW is: 86
# buy order quantity placed for MDLZ is: 198
# sell order quantity placed for MS is: 35
# buy order quantity placed for MSI is: 133
# buy order quantity placed for OKE is: 206
# buy order quantity placed for PNC is: 28
# sell order quantity placed for PYPL is: 57
# buy order quantity placed for ROST is: 315
# buy order quantity placed for SIRI is: 1078
# sell order quantity placed for SPGI is: 11
# buy order quantity placed for TSCO is: 92
# buy order quantity placed for ULTA is: 7
# sell order quantity placed for UNP is: 57
# sell order quantity placed for WIX is: 19

# %%
open_orders_all = account.get_openorders()
# Out:
# open order ended

# %%
open_orders_all
# Out:
#      action executed_orders type algoStrategy                algoParams  \
# POOL    BUY              13  MKT     Adaptive  adaptivePriority=Normal;
# THO     BUY              56  MKT     Adaptive  adaptivePriority=Normal;
# WDC    SELL             149  MKT     Adaptive  adaptivePriority=Normal;
# PKG     BUY              65  MKT     Adaptive  adaptivePriority=Normal;
# SIRI    BUY            1078  MKT     Adaptive  adaptivePriority=Normal;
# SAIC   SELL             180  MKT     Adaptive  adaptivePriority=Normal;
# TSCO    BUY              92  MKT     Adaptive  adaptivePriority=Normal;
# SQ      BUY              20  MKT     Adaptive  adaptivePriority=Normal;
# PII     BUY              58  MKT     Adaptive  adaptivePriority=Normal;
# UNP    SELL              57  MKT     Adaptive  adaptivePriority=Normal;
# PLAY   SELL             186  MKT     Adaptive  adaptivePriority=Normal;
# WIX    SELL              19  MKT     Adaptive  adaptivePriority=Normal;
# OMC    SELL              52  MKT     Adaptive  adaptivePriority=Normal;
# PYPL   SELL              57  MKT     Adaptive  adaptivePriority=Normal;
# KHC     BUY             225  MKT     Adaptive  adaptivePriority=Normal;
# ULTA    BUY               7  MKT     Adaptive  adaptivePriority=Normal;
# LDOS   SELL              29  MKT     Adaptive  adaptivePriority=Normal;
# PNC     BUY              28  MKT     Adaptive  adaptivePriority=Normal;
# JCOM   SELL             543  MKT     Adaptive  adaptivePriority=Normal;
# SPGI   SELL              11  MKT     Adaptive  adaptivePriority=Normal;
# JWN    SELL             165  MKT     Adaptive  adaptivePriority=Normal;
# MSI     BUY             133  MKT     Adaptive  adaptivePriority=Normal;
# FLIR   SELL              67  MKT     Adaptive  adaptivePriority=Normal;
# ROST    BUY             315  MKT     Adaptive  adaptivePriority=Normal;
# CLX     BUY              35  MKT     Adaptive  adaptivePriority=Normal;
# OKE     BUY             206  MKT     Adaptive  adaptivePriority=Normal;
# HPE    SELL             291  MKT     Adaptive  adaptivePriority=Normal;
# MS     SELL              35  MKT     Adaptive  adaptivePriority=Normal;
# AMD    SELL              47  MKT     Adaptive  adaptivePriority=Normal;
# HCA     BUY              42  MKT     Adaptive  adaptivePriority=Normal;
# DHI     BUY              63  MKT     Adaptive  adaptivePriority=Normal;
# MDLZ    BUY             198  MKT     Adaptive  adaptivePriority=Normal;
# CHD     BUY              62  MKT     Adaptive  adaptivePriority=Normal;
# LOW     BUY              86  MKT     Adaptive  adaptivePriority=Normal;
# BWA     BUY             100  MKT     Adaptive  adaptivePriority=Normal;
# GS     SELL              49  MKT     Adaptive  adaptivePriority=Normal;
# ADSK    BUY              13  MKT     Adaptive  adaptivePriority=Normal;
# ILMN   SELL              16  MKT     Adaptive  adaptivePriority=Normal;
# CACI   SELL              26  MKT     Adaptive  adaptivePriority=Normal;
# KO     SELL             782  MKT     Adaptive  adaptivePriority=Normal;
# GIS    SELL             121  MKT     Adaptive  adaptivePriority=Normal;
# IBM    SELL              14  MKT     Adaptive  adaptivePriority=Normal;
# FISV   SELL             118  MKT     Adaptive  adaptivePriority=Normal;
# DTE    SELL              36  MKT     Adaptive  adaptivePriority=Normal;
# CAT    SELL              71  MKT     Adaptive  adaptivePriority=Normal;
# ENPH    BUY              13  MKT     Adaptive  adaptivePriority=Normal;
# DLR    SELL              32  MKT     Adaptive  adaptivePriority=Normal;
# ETFC   SELL             148  MKT     Adaptive  adaptivePriority=Normal;
# AXP     BUY             108  MKT     Adaptive  adaptivePriority=Normal;
# CHGG   SELL              38  MKT     Adaptive  adaptivePriority=Normal;
# ANSS    BUY             104  MKT     Adaptive  adaptivePriority=Normal;
#
#              status
# POOL   PreSubmitted
# THO    PreSubmitted
# WDC   PendingSubmit
# PKG    PreSubmitted
# SIRI  PendingSubmit
# SAIC   PreSubmitted
# TSCO   PreSubmitted
# SQ    PendingSubmit
# PII    PreSubmitted
# UNP    PreSubmitted
# PLAY  PendingSubmit
# WIX    PreSubmitted
# OMC    PreSubmitted
# PYPL  PendingSubmit
# KHC   PendingSubmit
# ULTA   PreSubmitted
# LDOS   PreSubmitted
# PNC   PendingSubmit
# JCOM   PreSubmitted
# SPGI   PreSubmitted
# JWN   PendingSubmit
# MSI    PreSubmitted
# FLIR  PendingSubmit
# ROST   PreSubmitted
# CLX    PreSubmitted
# OKE   PendingSubmit
# HPE   PendingSubmit
# MS    PendingSubmit
# AMD   PendingSubmit
# HCA    PreSubmitted
# DHI    PreSubmitted
# MDLZ   PreSubmitted
# CHD    PreSubmitted
# LOW   PendingSubmit
# BWA    PreSubmitted
# GS    PendingSubmit
# ADSK   PreSubmitted
# ILMN   PreSubmitted
# CACI   PreSubmitted
# KO    PendingSubmit
# GIS    PreSubmitted
# IBM   PendingSubmit
# FISV   PreSubmitted
# DTE    PreSubmitted
# CAT   PendingSubmit
# ENPH  PendingSubmit
# DLR    PreSubmitted
# ETFC   PreSubmitted
# AXP   PendingSubmit
# CHGG  PendingSubmit
# ANSS   PreSubmitted

# %%
not_executed_action = open_orders_all.index ^ action_conc.index                        
print ('{} not executed'.format(list(not_executed_action)))
# Out:
# ['WING'] not executed

# %%
execution = pd.concat([action_conc, open_orders_all[['executed_orders']]],axis=1, sort=True)

# %%
execution
# Out:
#       portfolio_shares  balance_lev_shares  final_action_shares  \
# ALL                NaN                 NaN            35.511015
# ALTR               NaN                 NaN           -24.821708
# CBRE               NaN                 NaN            59.428589
# CLF                NaN                 NaN          -170.227157
# CWT                NaN                 NaN           -79.560792
# DRQ                NaN                 NaN           -14.395437
# ETR                NaN                 NaN            25.352741
# FLOW               NaN                 NaN           -15.620185
# GTN                NaN                 NaN           157.707817
# MAC                NaN                 NaN          -439.429358
# MCY                NaN                 NaN            -1.485331
# NXST               NaN                 NaN            24.565803
# PEB         -19.999999             -939.03           807.989027
# PK                 NaN                 NaN            31.848980
# SMSI         99.998787             4695.73                  NaN
# UFPI               NaN                 NaN            42.875291
# VGR                NaN                 NaN          -282.906356
#
#       target_shares executed_orders
# ALL       35.511015             NaN
# ALTR     -24.821708             NaN
# CBRE      59.428589             NaN
# CLF     -170.227157             NaN
# CWT      -79.560792             NaN
# DRQ      -14.395437             NaN
# ETR       25.352741             NaN
# FLOW     -15.620185             NaN
# GTN      157.707817             NaN
# MAC     -439.429358             NaN
# MCY       -1.485331             NaN
# NXST      24.565803             NaN
# PEB     -151.040972             NaN
# PK        31.848980             NaN
# SMSI            NaN             NaN
# UFPI      42.875291             NaN
# VGR     -282.906356             NaN

# %% [markdown]
# ## 11 - 6 - Commission report of last realized trades

# %%
df = account.commission_report(acctCode = account_number, time= '20200701')

# %%
execution_date = '2020-07-20'

# %%
df
# Out:
#                     ticker shares action   price marketValue RealizedPNL  \
# time
# 2020-07-13 09:30:01    WDC    100    BOT    42.8        4280        OPEN
# 2020-07-13 09:30:01   PYPL    106    BOT  180.74     19158.4    -1578.56
# 2020-07-13 09:30:01   INTU      8    SLD  308.81     2470.48     182.193
# 2020-07-13 09:30:01    KHC    225    SLD   32.31     7269.75        OPEN
# 2020-07-13 09:30:02    WDC     49    BOT    42.8      2097.2        OPEN
# 2020-07-13 09:30:03   WING     21    SLD  136.92     2875.32        OPEN
# 2020-07-13 09:30:03   PLAY    186    BOT   12.39     2304.54        OPEN
# 2020-07-13 09:30:05    CLX     18    BOT  230.96     4157.28    -262.405
# 2020-07-13 09:30:10   TSCO    117    SLD  139.36     16305.1        OPEN
# 2020-07-13 09:30:11    HPE    291    BOT    9.34     2717.94        OPEN
# 2020-07-13 09:30:12   TMUS     65    BOT  106.94      6951.1    -70.1634
# 2020-07-13 09:30:12    UAL    100    BOT    33.2        3320     4.22696
# 2020-07-13 09:30:12    UAL     40    BOT    33.2        1328     1.69078
# 2020-07-13 09:30:16   AMAT     79    SLD   63.09     4984.11     366.427
# 2020-07-13 09:30:19     KO      5    SLD   45.44       227.2     7.13366
# 2020-07-13 09:30:19     KO    200    SLD   45.47        9094     291.346
# 2020-07-13 09:30:19     KO    100    SLD   45.44        4544     142.673
# 2020-07-13 09:30:20    PII     58    SLD   95.68     5549.44        OPEN
# 2020-07-13 09:30:20   REGN      7    BOT   624.7      4372.9    -106.155
# 2020-07-13 09:30:20   JCOM    200    BOT   57.99       11598        OPEN
# 2020-07-13 09:30:21    MAR     28    SLD   88.89     2488.92     203.468
# 2020-07-13 09:30:24    JWN    100    BOT   15.97        1597        OPEN
# 2020-07-13 09:30:24      D    157    BOT   73.65     11563.1     1172.68
