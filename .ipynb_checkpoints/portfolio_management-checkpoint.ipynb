# %%
import matplotlib.pyplot as plt
import datetime as datetime
import numpy as np
import pandas as pd
import talib
import seaborn as sns
from time import time
import pytz

# %%
import risk_model
import factorize
import account

# %%
optimal_weights_regularized = pd.read_csv('optimal_weights_regularized.csv',index_col = 'asset')
close = pd.read_csv('close.csv', index_col = 'date')

# %% [markdown]
# # 1 - Portfolio Management

# %% [markdown]
# #### paper account: DU1440139
# #### margin account: U2909804

# %%
portfolio = account.read_positions(subscribe = True, acctCode = 'DU1440139')
# Out:
# PositionEnd
# Reading Portfolio

# %%
portfolio
# Out:
#         Position  marketPrice  marketValue  averageCost  unrealizedPNL  \
# Symbol
# AMAT       124.0    57.720001      7157.28    55.690571         251.65
# BDX         47.0   243.000000     11421.00   242.409091          27.77
# CME         75.0   185.759995     13932.00   183.783333         148.25
# COST        39.0   309.910004     12086.49   305.540172         170.42
# D         -297.0    85.305000    -25335.59    84.593011        -211.46
# EBAY       -50.0    48.209999     -2410.50    45.428876        -139.06
# EL         -23.0   203.214996     -4673.94   198.422017        -110.24
# FISV       260.0   108.500000     28210.00   106.474678         526.58
# GPN        115.0   189.100006     21746.50   179.898696        1058.15
# ILMN       -27.0   357.660004     -9656.82   356.554759         -29.84
# ISRG       -17.0   571.849976     -9721.45   565.688147        -104.75
# LOW       -123.0   131.649994    -16192.95   129.898880        -215.39
# LULU       -23.0   322.399994     -7415.20   299.659778        -523.02
# MCHP       -47.0   108.099998     -5080.70    95.266498        -603.17
# MS         -52.0    46.599998     -2423.20    44.189673        -125.34
# MSFT        62.0   184.440002     11435.28   183.976129          28.76
# NKE        -93.0   103.000000     -9579.00    98.306956        -436.45
# NXPI        47.0   107.500000      5052.50    97.741277         458.66
# OXY        177.0    15.030000      2660.31    12.815650         391.94
# PEP        123.0   131.794998     16210.78   131.263798          65.34
# ROKU        21.0   104.559998      2195.76   109.537619        -104.53
# SLB       -124.0    19.570000     -2426.68    18.516246        -130.67
# UNH        -37.0   302.250000    -11183.25   302.776162          19.47
# WDAY       -50.0   181.250000     -9062.50   181.555868          15.29
#
#         realizedPNL
# Symbol
# AMAT            0.0
# BDX             0.0
# CME             0.0
# COST            0.0
# D               0.0
# EBAY            0.0
# EL              0.0
# FISV            0.0
# GPN             0.0
# ILMN            0.0
# ISRG            0.0
# LOW             0.0
# LULU            0.0
# MCHP            0.0
# MS              0.0
# MSFT            0.0
# NKE             0.0
# NXPI            0.0
# OXY             0.0
# PEP             0.0
# ROKU            0.0
# SLB             0.0
# UNH             0.0
# WDAY            0.0

# %%
acc = account.read_account(reqId = 0, subscribe = True, acctCode = 'DU1440139')
# Out:
# AccountDownloadEnd. Account: DU1440139
# Reading Account

# %%
all_weights, long, short, grv = risk_model.portfolio_calculation(portfolio)

# %%
all_weights
# Out:
#         weights
# Symbol
# AMAT     0.0289
# BDX      0.0462
# CME      0.0563
# COST     0.0489
# D       -0.1025
# EBAY    -0.0097
# EL      -0.0189
# FISV     0.1141
# GPN      0.0879
# ILMN    -0.0391
# ISRG    -0.0393
# LOW     -0.0655
# LULU    -0.0300
# MCHP    -0.0205
# MS      -0.0098
# MSFT     0.0462
# NKE     -0.0387
# NXPI     0.0204
# OXY      0.0108
# PEP      0.0656
# ROKU     0.0089
# SLB     -0.0098
# UNH     -0.0452
# WDAY    -0.0367

# %%
x = range(len(all_weights))
y = all_weights.values.flatten()
fig, ax = plt.subplots(figsize=(20, 10))
plt.grid(True)
plt.bar(x, y, width = 0.8, linewidth = 1, color='orange')
plt.xticks(x, tuple(all_weights.index))
plt.tick_params(labelrotation=90)
plt.show()

# %%
acc.head(50)
# Out:
#                            Values
# Keys
# AccountCode             DU1440139
# AccountOrGroup          DU1440139
# AccountReady                 true
# AccountType            INDIVIDUAL
# AccruedCash                     0
# AccruedCash-C                   0
# AccruedCash-S                   0
# AccruedDividend                 0
# AccruedDividend-C               0
# AccruedDividend-S               0
# AvailableFunds              85053
# AvailableFunds-C                0
# AvailableFunds-S            85053
# Billable                        0
# Billable-C                      0
# Billable-S                      0
# BuyingPower                338263
# CashBalance                135826
# CorporateBondValue              0
# Currency                      USD
# Cushion                         1
# DayTradesRemaining             -1
# DayTradesRemainingT+1          -1
# DayTradesRemainingT+2          -1
# DayTradesRemainingT+3          -1
# DayTradesRemainingT+4          -1
# EquityWithLoanValue        152629
# EquityWithLoanValue-C           0
# EquityWithLoanValue-S      152629
# ExcessLiquidity             85197
# ExcessLiquidity-C               0
# ExcessLiquidity-S           85197
# ExchangeRate                    1
# FullAvailableFunds          85053
# FullAvailableFunds-C            0
# FullAvailableFunds-S        85053
# FullExcessLiquidity         85197
# FullExcessLiquidity-C           0
# FullExcessLiquidity-S       85197
# FullInitMarginReq           67576
# FullInitMarginReq-C             0
# FullInitMarginReq-S         67576
# FullMaintMarginReq          67576
# FullMaintMarginReq-C            0
# FullMaintMarginReq-S        67576
# FundValue                       0
# FutureOptionValue               0
# FuturesPNL                      0
# FxCashBalance                   0
# GrossPositionValue         247270

# %%
long_value = long['marketValue'].sum()
short_value = short['marketValue'].sum()
print ('Buying Power: {} $'.format(np.round(float(acc.loc['BuyingPower',:].values[0]), 4)))
print ('Gross Market Value: {} $'.format(np.round(grv, 4)))
print (' Long Value: {} $'.format(np.round(long_value,4)))
print (' Short Value: {} $'.format(np.round(short_value,4)))
print (' Net Liquidation: {} $'.format(np.round(float(acc.loc['EquityWithLoanValue',:].values[0]),4)))
print (' Unrealize PNL: {} $'.format(np.round(portfolio['unrealizedPNL'].sum()),4))
print (' Loan Value: {} $'.format(np.round(float(acc.loc['GrossPositionValue'][0]) - float(acc.loc['EquityWithLoanValue'][0]), 4)))
print ('#####################################')
print ('Leverage Value: {}'.format(np.round(grv/float(acc.loc['EquityWithLoanValue'][0]), 4)))
print (' Long Leverage Value: {}'.format(np.round(long_value/float(acc.loc['EquityWithLoanValue'][0]), 4)))
print (' Short Leverage Value: {}'.format(np.round(np.abs(short_value)/float(acc.loc['EquityWithLoanValue'][0]), 4)))
# Out:
# Buying Power: 338263.0 $
# Gross Market Value: 247269.68 $
#  Long Value: 132107.9 $
#  Short Value: -115161.78 $
#  Net Liquidation: 152629.0 $
#  Unrealize PNL: 428.0 $
#  Loan Value: 94641.0 $
# #####################################
# Leverage Value: 1.6201
#  Long Leverage Value: 0.8655
#  Short Leverage Value: 0.7545

# %%
universe = portfolio.index
long_universe = long.index 
short_universe = short.index

# %%
net_liq = np.round(float(acc.loc['EquityWithLoanValue',:].values[0]),4)

# %% [markdown]
# ## 11 - 1 - Portfolio cash balance

# %%
target_leverage = 1.5
grv_target = net_liq * target_leverage
excess_grv = grv_target - grv
print (excess_grv,'$')
marketVal_target = all_weights * grv_target
# Out:
# -18326.179999999993 $

# %%
balancing_order = marketVal_target['weights'] - portfolio['marketValue']
df_port = portfolio['marketPrice']
action_balance = pd.DataFrame(index = df_port.index, columns = ['shares'])
action_balance['shares'] = np.round(balancing_order / df_port,2)
to_drop = action_balance[action_balance['shares']==0.0].index
action_balance.drop(to_drop,axis=0,inplace=True)

# %% [markdown]
# ## 11 - 1 - Projected portfolio

# %%
val = account.read_nextvalidid(reqId=-1)
# Out:
# NextValidId: 618

# %% [markdown]
# ## Gets actual open orders and canceled before rebalancing

# %% [markdown]
# ### Balancing

# %%
#account.rebalancing_to_leverage(action_balance = action_balance , order_id = val)

# %% [markdown]
# ## 11 - 2 - Filtering stock with good market value

# %% [markdown]
# Here we are keeping stocks subjected to more than 500 market value trade for the actual rebalance period. We also rebalance stocks with more than 200 dollar variation

# %%
df_c = pd.DataFrame(data=close[optimal_weights_regularized.index].iloc[-1].values,
                   index = close[optimal_weights_regularized.index].iloc[-1].index,
                   columns = ['close'])
df_c.index.name = 'asset'

# %%
optimal_weights_regularized_rounded = np.round(optimal_weights_regularized,2)
optimal_selected = optimal_weights_regularized_rounded[optimal_weights_regularized_rounded['optimal_weights'] != 0.00]

# %%
stock_to_balance = portfolio.index & optimal_selected.index
stock_to_close = portfolio.index ^ stock_to_balance

# %%
df_c_target = df_c.reindex(optimal_selected.index)
shares_target_float = (optimal_selected * grv_target)['optimal_weights']/df_c_target['close']

# %%
portfolio_shares_float = portfolio['marketValue'] / portfolio['marketPrice']

# %%
# Rebalance to optimal weights
action_final = pd.DataFrame(index = shares_target_float.index, columns = ['shares'])

for i in shares_target_float.index:
    
    if (i in stock_to_balance) and (i not in action_balance.index):
        action_final.loc[i,'shares'] = shares_target_float[i] - portfolio_shares_float[i]
        
    elif (i in stock_to_balance) and (i in action_balance.index):
        action_final.loc[i,'shares'] = shares_target_float[i] - portfolio_shares_float[i] - action_balance['shares'][i]

    elif (i in action_balance.index) and (i not in stock_to_balance):
        action_final.loc[i,'shares'] = shares_target_float[i] - action_balance['shares'][i]
    else:
        action_final.loc[i,'shares'] = shares_target_float[i]

# %%
portfolio_shares_float = pd.DataFrame(portfolio_shares_float,columns = ['portfolio_shares'],index=portfolio_shares_float.index)
shares_target_float = pd.DataFrame(shares_target_float,columns = ['target_shares'],index=shares_target_float.index)
action_balance.columns = ['balance_lev_shares']
action_final.columns = ['final_action_shares']

# %%
portfolio_shares = portfolio_shares_float.astype('int')

# %%
action_conc = pd.concat([portfolio_shares,action_balance,action_final,shares_target_float],axis=1,sort ='False')

# %%
action_conc
# Out:
#       portfolio_shares  balance_lev_shares final_action_shares  target_shares
# AMAT             123.0               -9.37            -75.0272      39.602750
# BDX               47.0               -3.47                 NaN            NaN
# BKNG               NaN                 NaN             3.97939       3.979388
# CCI                NaN                 NaN            -39.3464     -39.346385
# CLX                NaN                 NaN            -55.5769     -55.576904
# CME               75.0               -5.61                 NaN            NaN
# COST              38.0               -2.88             83.3392     119.459170
# CRWD               NaN                 NaN            -70.0133     -70.013303
# D               -297.0               21.91                 NaN            NaN
# DPZ                NaN                 NaN            -5.86824      -5.868240
# EBAY             -50.0                3.94            -52.5163     -98.576319
# EL               -22.0                1.71            -23.7688     -45.058748
# FDX                NaN                 NaN             -33.161     -33.160994
# FIS                NaN                 NaN              65.614      65.613957
# FISV             260.0              -19.24                 NaN            NaN
# GPN              114.0               -8.58                 NaN            NaN
# HCA                NaN                 NaN             42.4205      42.420511
# ILMN             -26.0                1.97                 NaN            NaN
# ISRG             -17.0                1.27                 NaN            NaN
# LOW             -123.0                9.09                 NaN            NaN
# LULU             -23.0                1.70             -21.131     -42.430994
# MCHP             -47.0                3.58                 NaN            NaN
# MCK                NaN                 NaN            -42.4703     -42.470350
# MDLZ               NaN                 NaN            -87.9031     -87.903052
# MDT                NaN                 NaN             117.891     117.890577
# MMM                NaN                 NaN            -14.2016     -14.201569
# MS               -52.0                3.85                 NaN            NaN
# MSFT              61.0               -4.65             4.40645      61.756447
# NKE              -93.0                6.98            -23.9327    -109.952694
# NOC                NaN                 NaN             40.8876      40.887635
# NXPI              47.0               -3.55            -22.3589      21.091064
# OXY              177.0              -12.49                 NaN            NaN
# PEP              122.0               -9.05            -62.2386      51.711376
# PYPL               NaN                 NaN            -43.8086     -43.808553
# REGN               NaN                 NaN            -18.9435     -18.943495
# ROKU              21.0               -1.51                 NaN            NaN
# SLB             -124.0                9.35                 NaN            NaN
# SPGI               NaN                 NaN             -20.602     -20.602031
# UNH              -37.0                2.76                 NaN            NaN
# W                  NaN                 NaN            -12.6063     -12.606327
# WDAY             -50.0                3.64                 NaN            NaN
# WDC                NaN                 NaN             100.767     100.767386
# WMT                NaN                 NaN             37.0849      37.084879
# XLNX               NaN                 NaN            -48.0016     -48.001572

# %%
canceled_open_orders = account.cancel_openorders()
# Out:
# open order ended
# open order ended

# %%
open_orders = account.get_openorders()
# Out:
# open order ended

# %%
if open_orders.index.empty:
    print ('we are good to go')
else:
    print ('check tws')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-c48140c9e9e6> in <module>
# ----> 1 if open_orders.index.empty:
#       2     print ('we are good to go')
#       3 else:
#       4     print ('check tws')
#
# NameError: name 'open_orders' is not defined

# %%
# closing positions not in shares target
account.closing_positions(stock_to_close = stock_to_close, portfolio = portfolio , order_id = val)
# Out:
# app is running ...
# closing 21 positions which are not present in action
# closing position for ADP is: 127
# closing ALGN position is: 45
# closing position for BBY is: 68
# closing BYND position is: 63
# closing CL position is: 191
# closing CSX position is: 103
# closing FB position is: 28
# closing position for LMT is: 43
# closing position for LRCX is: 7
# closing MO position is: 117
# closing MRVL position is: 91
# closing position for MSFT is: 111
# closing position for MU is: 9
# closing position for PG is: 151
# closing PM position is: 83
# closing position for QCOM is: 36
# closing SE position is: 104
# closing T position is: 250
# closing position for TIF is: 47
# closing TWTR position is: 49
# closing UNP position is: 21

# %%
open_orders_closing = account.get_openorders()
# Out:
# open order ended

# %%
open_orders_closing
# Out:
# Empty DataFrame
# Columns: [action, quantity, type, algoStrategy, algoParams, status]
# Index: []

# %%
not_executed = open_orders_closing.index ^ stock_to_close
if not_executed.empty:
    print ('good to go for final action')
else:
    print ('place {} order manually on tws'.format(not_executed[0]))
# Out:
# place ADP order manually on tws

# %%
action_final = action_final.astype('int')
account.placing_final_orders(action_final=action_final, order_id = val)
# Out:
# buy order quantity placed for FISV is: 184
# buy order quantity placed for GPN is: 115
# buy order quantity placed for BDX is: 30
# buy order quantity placed for ILMN is: 18
# buy order quantity placed for ISRG is: 3
#  sell order quantity placed for UNH is: 37
# buy order quantity placed for OXY is: 177
#  sell order quantity placed for SLB is: 124
#  sell order quantity placed for COST is: 6
#  sell order quantity placed for EL is: 23
# buy order quantity placed for PEP is: 79
#  sell order quantity placed for LOW is: 123
#  sell order quantity placed for LULU is: 23
#  sell order quantity placed for NKE is: 93
# buy order quantity placed for AMAT is: 50
#  sell order quantity placed for EBAY is: 50
#  sell order quantity placed for MCHP is: 47
# buy order quantity placed for NXPI is: 47
#  sell order quantity placed for WDAY is: 50
# buy order quantity placed for ROKU is: 21
#  sell order quantity placed for D is: 297
# buy order quantity placed for CME is: 75
#  sell order quantity placed for MS is: 52

# %%
open_orders_all = account.get_openorders()
# Out:
# open order ended

# %%
open_orders_all
# Out:
# Empty DataFrame
# Columns: [action, executed_orders, type, algoStrategy, algoParams, status]
# Index: []

# %%
not_executed_action = open_orders_all.index ^ action_conc.index                        
list(not_executed_action)
# Out:
# ['AMAT',
#  'BDX',
#  'BKNG',
#  'CCI',
#  'CLX',
#  'CME',
#  'COST',
#  'CRWD',
#  'D',
#  'DPZ',
#  'EBAY',
#  'EL',
#  'FDX',
#  'FIS',
#  'FISV',
#  'GPN',
#  'HCA',
#  'ILMN',
#  'ISRG',
#  'LOW',
#  'LULU',
#  'MCHP',
#  'MCK',
#  'MDLZ',
#  'MDT',
#  'MMM',
#  'MS',
#  'MSFT',
#  'NKE',
#  'NOC',
#  'NXPI',
#  'OXY',
#  'PEP',
#  'PYPL',
#  'REGN',
#  'ROKU',
#  'SLB',
#  'SPGI',
#  'UNH',
#  'W',
#  'WDAY',
#  'WDC',
#  'WMT',
#  'XLNX']

# %%
execution = pd.concat([action_conc, open_orders_all[['executed_orders']]],axis=1, sort=True)

# %%
execution
# Out:
#       portfolio_shares  balance_lev_shares final_action_shares  target_shares  \
# AMAT             123.0               -9.37            -75.0272      39.602750
# BDX               47.0               -3.47                 NaN            NaN
# BKNG               NaN                 NaN             3.97939       3.979388
# CCI                NaN                 NaN            -39.3464     -39.346385
# CLX                NaN                 NaN            -55.5769     -55.576904
# CME               75.0               -5.61                 NaN            NaN
# COST              38.0               -2.88             83.3392     119.459170
# CRWD               NaN                 NaN            -70.0133     -70.013303
# D               -297.0               21.91                 NaN            NaN
# DPZ                NaN                 NaN            -5.86824      -5.868240
# EBAY             -50.0                3.94            -52.5163     -98.576319
# EL               -22.0                1.71            -23.7688     -45.058748
# FDX                NaN                 NaN             -33.161     -33.160994
# FIS                NaN                 NaN              65.614      65.613957
# FISV             260.0              -19.24                 NaN            NaN
# GPN              114.0               -8.58                 NaN            NaN
# HCA                NaN                 NaN             42.4205      42.420511
# ILMN             -26.0                1.97                 NaN            NaN
# ISRG             -17.0                1.27                 NaN            NaN
# LOW             -123.0                9.09                 NaN            NaN
# LULU             -23.0                1.70             -21.131     -42.430994
# MCHP             -47.0                3.58                 NaN            NaN
# MCK                NaN                 NaN            -42.4703     -42.470350
# MDLZ               NaN                 NaN            -87.9031     -87.903052
# MDT                NaN                 NaN             117.891     117.890577
# MMM                NaN                 NaN            -14.2016     -14.201569
# MS               -52.0                3.85                 NaN            NaN
# MSFT              61.0               -4.65             4.40645      61.756447
# NKE              -93.0                6.98            -23.9327    -109.952694
# NOC                NaN                 NaN             40.8876      40.887635
# NXPI              47.0               -3.55            -22.3589      21.091064
# OXY              177.0              -12.49                 NaN            NaN
# PEP              122.0               -9.05            -62.2386      51.711376
# PYPL               NaN                 NaN            -43.8086     -43.808553
# REGN               NaN                 NaN            -18.9435     -18.943495
# ROKU              21.0               -1.51                 NaN            NaN
# SLB             -124.0                9.35                 NaN            NaN
# SPGI               NaN                 NaN             -20.602     -20.602031
# UNH              -37.0                2.76                 NaN            NaN
# W                  NaN                 NaN            -12.6063     -12.606327
# WDAY             -50.0                3.64                 NaN            NaN
# WDC                NaN                 NaN             100.767     100.767386
# WMT                NaN                 NaN             37.0849      37.084879
# XLNX               NaN                 NaN            -48.0016     -48.001572
#
#      executed_orders
# AMAT             NaN
# BDX              NaN
# BKNG             NaN
# CCI              NaN
# CLX              NaN
# CME              NaN
# COST             NaN
# CRWD             NaN
# D                NaN
# DPZ              NaN
# EBAY             NaN
# EL               NaN
# FDX              NaN
# FIS              NaN
# FISV             NaN
# GPN              NaN
# HCA              NaN
# ILMN             NaN
# ISRG             NaN
# LOW              NaN
# LULU             NaN
# MCHP             NaN
# MCK              NaN
# MDLZ             NaN
# MDT              NaN
# MMM              NaN
# MS               NaN
# MSFT             NaN
# NKE              NaN
# NOC              NaN
# NXPI             NaN
# OXY              NaN
# PEP              NaN
# PYPL             NaN
# REGN             NaN
# ROKU             NaN
# SLB              NaN
# SPGI             NaN
# UNH              NaN
# W                NaN
# WDAY             NaN
# WDC              NaN
# WMT              NaN
# XLNX             NaN

# %%
df = account.commission_report(acctCode = 'DU1440139', time= '20200531')

# %%
execution_date = '2020-06-01'

# %%
df.loc[slice(execution_date)]
# Out:
#                     ticker action shares   price marketValue RealizedPNL  \
# time
# 2020-05-29 09:30:01   FISV    SLD     22  105.94     2330.68     13.3222
# 2020-05-29 09:30:04   ISRG    BOT      6     582        3492    -98.8711
# 2020-05-29 09:30:07   LRCX    SLD      2  269.79      539.58     1.29228
# 2020-05-29 09:30:08     MO    BOT     34   38.56     1311.04     19.4476
# 2020-05-29 09:30:09   COST    SLD     13  304.01     3952.13    -20.9811
# ...                    ...    ...    ...     ...         ...         ...
# 2020-06-01 09:30:57    GPN    BOT    100  179.83       17983        OPEN
# 2020-06-01 09:31:00     PG    SLD     51  115.85     5908.35      175.22
# 2020-06-01 09:31:29    GPN    BOT     15  180.29     2704.35        OPEN
# 2020-06-01 09:31:48     SE    BOT    100   81.39        8139     79.0657
# 2020-06-01 09:31:51     SE    BOT      4   81.37      325.48     3.28263
#
#                     commission
# time
# 2020-05-29 09:30:01    1.05413
# 2020-05-29 09:30:04          1
# 2020-05-29 09:30:07    1.01216
# 2020-05-29 09:30:08          1
# 2020-05-29 09:30:09    1.08889
# ...                        ...
# 2020-06-01 09:30:57          1
# 2020-06-01 09:31:00   0.136644
# 2020-06-01 09:31:29          0
# 2020-06-01 09:31:48          1
# 2020-06-01 09:31:51          0
#
# [83 rows x 7 columns]

# %%
RealizedPNL = np.round(pd.to_numeric(df.loc[slice(execution_date)]['RealizedPNL'], errors='coerce').sum(),2)
Total_Realized_Return = np.round((RealizedPNL/net_liq)*100,2)
print ('Report for {}:'.format(execution_date))
print (' Market Value: {} $'.format(np.round(df.loc[slice(execution_date)]['marketValue'].sum(),2)))
print (' Total Commission: {} $'.format(np.round(df.loc[slice(execution_date)]['commission'].sum(),2)))
print (' Total Realized PNL: {} $'.format(RealizedPNL))  
print (' Total Realized Return: {} %'.format(Total_Realized_Return))
# Out:
# Report for 2020-06-01:
#  Market Value: 421997.41 $
#  Total Commission: 77.65 $
#  Total Realized PNL: 3475.18 $
#  Total Realized Return: 2.28 %
