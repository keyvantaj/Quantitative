# %%
import utils
import matplotlib.pyplot as plt
from datetime import datetime

# %%
symbol = 'ADBE'
print ('Data Generated for {}'.format(symbol))
# Out:
# Data Generated for ADBE

# %% [markdown]
# #### *ReportSnapshot: Company overview*
# #### *ReportsFinSummary: Financial summary*
# #### *ReportRatios: Financial ratios*
# #### *ReportsFinStatements: Financial statements*
# #### *RESC: Analyst estimates*
# #### *CalendarReport: Company calendar from Wall Street Horizons*

# %%
resc = utils.read_fundamental(reqId = 0,
                             symbol = symbol, 
                             sec_type = 'STK', 
                             exch = 'SMART', 
                             prim_exch = 'NASDAQ', 
                             curr = 'USD',
                             reportType = 'RESC')
# Out:
# Reading XML data ...

# %%
reportsnapshot = utils.read_fundamental(reqId=0,
                             symbol = symbol, 
                             sec_type = 'STK', 
                             exch = 'SMART', 
                             prim_exch = 'NASDAQ', 
                             curr = 'USD',
                             reportType = 'ReportSnapshot')
# Out:
# Reading XML data ...

# %%
reportsfinsummary = utils.read_fundamental(reqId=0,
                             symbol = symbol, 
                             sec_type = 'STK', 
                             exch = 'SMART', 
                             prim_exch = 'NASDAQ', 
                             curr = 'USD',
                             reportType = 'ReportsFinSummary')
# Out:
# Reading XML data ...

# %%
reportsfinstatements = utils.read_fundamental(reqId = 0,
                             symbol = symbol, 
                             sec_type = 'STK', 
                             exch = 'SMART', 
                             prim_exch = 'NASDAQ', 
                             curr = 'USD',
                             reportType = 'ReportsFinStatements')
# Out:
# Reading XML data ...

# %%
analyst, resc_ann, resc_q = utils.parse_resc(parser = resc)
snap, estimate, brief, business_summary, address = utils.parse_reportsnapshot(parser = reportsnapshot)
#fin = utils.parse_reportsfinsummary(parser = reportsfinsummary)
quarter, annual = utils.parse_reportsfinstatements(parser = reportsfinstatements)
# Out:
# Parsing resc data started ...
# Parsing reportsnapshot data started...
# Parsing reportsfinstatements data started...

# %%
snap
# Out:
#            Company Type          Desc Exchange    Index              Industry
# Adobe Inc  Equity Issue  Common Stock   NASDAQ  S&P 500  Application Software

# %%
analyst
# Out:
#           Exchange Symbol      Sector     CLPRICE  SHARESOUT    MARKETCAP  \
# Adobe Inc   NASDAQ   ADBE  Technology  282.130000  485438762  136956.8379
#
#            52WKHIGH   52WKLOW
# Adobe Inc  313.1100  204.9500

# %%
estimate
# Out:
#            ConsRecom  ProjDPS  ProjEPS  ProjEPSQ  ProjLTGrowthRate    ProjPE  \
# Adobe Inc     2.0357      0.0   7.8388    2.2574           16.1667  36.90488
#
#            ProjProfit   ProjSales  ProjSalesQ  TargetPrice
# Adobe Inc   3856.6064  11153.7929   2972.8089       316.76

# %%
resc_q.head()
# Out:
#           NAV OPROFIT   CAPEX  NPROFIT   ROA    CPS   EPS  REVENUE     EBIT  \
# 2019-05   NaN     NaN  85.492  900.604   NaN   2.25  1.83  2744.28  1049.93
# 2019-02   NaN     NaN  65.268      844   NaN  2.049  1.65     2580    984.6
# 2018-11 -6.74     NaN  62.563  942.203   NaN   2.24   1.9     2440  988.447
# 2018-08   NaN     NaN  63.558  859.764   NaN   1.92  1.73  2291.08  924.515
# 2018-05   NaN     NaN  45.316  825.427  19.3   1.96  1.66  2195.36  877.635
#
#             BVPS NPROFITREP PPROFIT EPSREP PPROFITREP   EBITDA    NDEBT  \
# 2019-05  20.3539    632.593     NaN   1.29        NaN  1098.83  654.627
# 2019-02  20.2076    674.241     NaN   1.31        NaN   1129.5 -3226.26
# 2018-11     19.2     732.24     NaN   1.48        NaN  1029.77  895.838
# 2018-08  18.1223    666.291     NaN   1.34        NaN   966.59 -3069.82
# 2018-05  17.6774    663.167     NaN   1.33        NaN  869.409 -4460.01
#
#            ROE  DPS
# 2019-05  36.38    0
# 2019-02    NaN  NaN
# 2018-11  41.36    0
# 2018-08  39.15    0
# 2018-05  38.08    0

# %%
quarter.columns.values
# Out:
# array(['Revenue', 'Total Revenue', 'Cost of Revenue, Total',
#        'Gross Profit', 'Selling/General/Admin. Expenses, Total',
#        'Research & Development', 'Depreciation/Amortization',
#        'Total Operating Expense', 'Operating Income',
#        'Interest Inc.(Exp.),Net-Non-Op., Total', 'Other, Net',
#        'Net Income Before Taxes', 'Provision for Income Taxes',
#        'Net Income After Taxes', 'Net Income Before Extra. Items',
#        'Net Income', 'Income Available to Com Excl ExtraOrd',
#        'Income Available to Com Incl ExtraOrd', 'Diluted Net Income',
#        'Diluted Weighted Average Shares',
#        'Diluted EPS Excluding ExtraOrd Items',
#        'DPS - Common Stock Primary Issue', 'Diluted Normalized EPS',
#        'Cash & Equivalents', 'Short Term Investments',
#        'Cash and Short Term Investments',
#        'Accounts Receivable - Trade, Net', 'Total Receivables, Net',
#        'Prepaid Expenses', 'Other Current Assets, Total',
#        'Total Current Assets', 'Property/Plant/Equipment, Total - Net',
#        'Goodwill, Net', 'Intangibles, Net',
#        'Other Long Term Assets, Total', 'Total Assets',
#        'Accounts Payable', 'Accrued Expenses',
#        'Notes Payable/Short Term Debt',
#        'Current Port. of  LT Debt/Capital Leases',
#        'Other Current liabilities, Total', 'Total Current Liabilities',
#        'Long Term Debt', 'Total Long Term Debt', 'Total Debt',
#        'Deferred Income Tax', 'Other Liabilities, Total',
#        'Total Liabilities', 'Preferred Stock - Non Redeemable, Net',
#        'Common Stock, Total', 'Additional Paid-In Capital',
#        'Retained Earnings (Accumulated Deficit)',
#        'Treasury Stock - Common', 'Unrealized Gain (Loss)',
#        'Other Equity, Total', 'Total Equity',
#        "Total Liabilities & Shareholders' Equity",
#        'Total Common Shares Outstanding',
#        'Tangible Book Value per Share, Common Eq',
#        'Net Income/Starting Line', 'Depreciation/Depletion',
#        'Deferred Taxes', 'Non-Cash Items', 'Cash Taxes Paid',
#        'Cash Interest Paid', 'Changes in Working Capital',
#        'Cash from Operating Activities', 'Capital Expenditures',
#        'Other Investing Cash Flow Items, Total',
#        'Cash from Investing Activities', 'Financing Cash Flow Items',
#        'Issuance (Retirement) of Stock, Net',
#        'Cash from Financing Activities', 'Foreign Exchange Effects',
#        'Net Change in Cash', 'Issuance (Retirement) of Debt, Net',
#        'Total Extraordinary Items'], dtype=object)

# %%
quarter
# Out:
#             Revenue Total Revenue Cost of Revenue, Total Gross Profit  \
# Quarter
# 2019-08-30  2834.13       2834.13                415.963      2418.16
# 2019-05-31  2744.28       2744.28                407.488      2336.79
# 2019-03-01  2600.95       2600.95                397.286      2203.66
# 2018-11-30  2464.62       2464.62                359.261      2105.36
# 2018-08-31  2291.08       2291.08                295.492      1995.58
#
#            Selling/General/Admin. Expenses, Total Research & Development  \
# Quarter
# 2019-08-30                                1031.57                489.827
# 2019-05-31                                1068.26                475.958
# 2019-03-01                                997.627                464.637
# 2018-11-30                                935.928                415.958
# 2018-08-31                                854.147                398.957
#
#            Depreciation/Amortization Total Operating Expense Operating Income  \
# Quarter
# 2019-08-30                    42.954                 1980.31          853.812
# 2019-05-31                    43.026                 1994.73          749.547
# 2019-03-01                    46.566                 1906.12           694.83
# 2018-11-30                    32.932                 1744.08          720.546
# 2018-08-31                    23.874                 1572.47          718.606
#
#            Interest Inc.(Exp.),Net-Non-Op., Total            ...             \
# Quarter                                                      ...
# 2019-08-30                                -20.556            ...
# 2019-05-31                                -48.054            ...
# 2019-03-01                                 -6.334            ...
# 2018-11-30                                -26.757            ...
# 2018-08-31                                -28.265            ...
#
#            Capital Expenditures Other Investing Cash Flow Items, Total  \
# Quarter
# 2019-08-30             -300.384                                 13.209
# 2019-05-31              -210.76                                 88.915
# 2019-03-01              -65.268                                 -66.65
# 2018-11-30             -266.579                               -4418.72
# 2018-08-31             -204.016                                -1342.4
#
#            Cash from Investing Activities Financing Cash Flow Items  \
# Quarter
# 2019-08-30                       -287.175                  -412.624
# 2019-05-31                       -121.845                  -376.706
# 2019-03-01                       -131.918                  -352.575
# 2018-11-30                        -4685.3                  -393.193
# 2018-08-31                       -1546.42                   -368.91
#
#            Issuance (Retirement) of Stock, Net Cash from Financing Activities  \
# Quarter
# 2019-08-30                            -1767.76                       -2180.38
# 2019-05-31                            -1176.09                       -1556.01
# 2019-03-01                            -428.406                       -783.912
# 2018-11-30                            -1859.01                         -5.568
# 2018-08-31                            -1560.26                        -1930.3
#
#            Foreign Exchange Effects Net Change in Cash  \
# Quarter
# 2019-08-30                  -11.583            566.272
# 2019-05-31                   -4.783            440.135
# 2019-03-01                   -1.547             96.071
# 2018-11-30                   -1.738           -663.297
# 2018-08-31                   -3.523           -558.928
#
#            Issuance (Retirement) of Debt, Net Total Extraordinary Items
# Quarter
# 2019-08-30                                NaN                       NaN
# 2019-05-31                             -3.219                       NaN
# 2019-03-01                             -2.931                       NaN
# 2018-11-30                           2246.635                      -6.0
# 2018-08-31                             -1.132                     -24.0
#
# [5 rows x 77 columns]

# %%
int(datetime.strptime(str(quarter.index[0]), '%Y-%m-%d').timestamp())
# Out:
# 1567137600
